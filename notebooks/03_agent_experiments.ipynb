# %% [markdown]
# # 03 — Agent Experiments
#
# This notebook is for experimenting with the LangChain compliance checker agent.
# Implement `ComplianceCheckerAgent` in `src/taxonomy_rag/agents/compliance_checker.py`
# and the tools in `src/taxonomy_rag/agents/tools/` before working here.

# %%
from dotenv import load_dotenv
load_dotenv()

from taxonomy_rag.config import settings
from taxonomy_rag.db.repository import DocumentRepository
from taxonomy_rag.llm.provider import get_llm

repo = DocumentRepository()
docs = repo.get_all(limit=1)
print(f"Connected. LLM provider: {settings.llm_provider}")
print(f"Documents in DB: {'0 (run ingest.py first)' if not docs else 'found'}")

# %% [markdown]
# ## 1. Tool definitions
#
# Test the individual LangChain tools: `search_taxonomy`, `get_article`, `filter_by_document`, `filter_by_annex`.

# %% [markdown]
# ## 2. ComplianceCheckerAgent
#
# Wire up the agent with the tools and run it against the golden dataset questions.

# %% [markdown]
# ## 3. Agent trace inspection
#
# Inspect intermediate steps, tool calls, and reasoning to understand agent behaviour.

# %% [markdown]
# ## 4. Comparison with plain RAG
#
# Compare agent answers vs. NaiveRAG / HybridRAG on the same questions.
